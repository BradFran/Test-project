# %% [markdown]
# This is a test project to learn VS Code, Git, GitHub, UV using Python and Jupyter Notebooks.
#
# Be sure to clear outputs before committing!

# %%
import pandas as pd
import matplotlib as plt

# %%
#define a data set and create a data frame

data = [{'a': 1, 'b': 2, 'c': 3},
        {'a': 10, 'b': 20, 'c': 30},
        {'a': 100, 'b': 200, 'c': 300}]

df = pd.DataFrame(data)

print(df)
# Out:
#      a    b    c
# 0    1    2    3
# 1   10   20   30
# 2  100  200  300

# %%
#plot the data frame

df.plot(kind='bar')
# Out:
# <Axes: >

# %%
print('End of Notebook!')
# Out:
# End of Notebook!
